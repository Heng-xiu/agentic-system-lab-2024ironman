# %% [markdown]
# # 🥱 吳恩達_反思翻譯代理人實踐篇
#
# 專案簡介
# Translation-Agent 是一個創新的 AI 驅動翻譯工具，旨在提供高質量的文本翻譯，並加入反思和優化的功能。這個專案不僅僅是簡單的語言轉換，更是一個能夠思考、改進並提供深度語言轉換的智能系統。
#
# ##主要功能
# 本專案將執行以下核心動作：
# 1. 文本翻譯：將源語言文本翻譯成目標語言
# 2. 翻譯質量評估：對初次翻譯結果進行自我評估
# 3. 反思與優化：基於評估結果，提出改進建議
# 4. 二次翻譯：根據反思結果，對原翻譯進行優化
# 5. 最終輸出：提供經過反思和優化的高質量翻譯結果
#
# ❤️ Created by [hengshiousheu](https://huggingface.co/Heng666).

# %% [markdown]
# # 在 Google Colab 中使用 Poetry 設置 Translation-Agent

# %% [markdown]
# 本教程將指導您如何在 Google Colab 環境中使用 Poetry 來管理 Python 專案的依賴。我們將以一個範例專案為例，展示整個流程。

# %% [markdown]
# ## 專案初始設置
# 首先，我們需要在 Colab 環境中設置我們的工作目錄。

# %%
# Move in your Drive
import os
os.chdir("/content")

# %% [markdown]
# ## 從 GitHub 克隆專案
#
# 接下來，我們將從 GitHub 克隆一個使用 Poetry 管理依賴的專案。

# %%
from pathlib import Path

repo_url = "https://github.com/Heng-xiu/translation-agent.git"
repo_name = Path(repo_url).stem

print(f"Repo name: {repo_name}")

# 克隆儲存庫
# !git clone {repo_url}

# 切換到專案目錄
# %cd repo_name
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Repo name: translation-agent

# %% [markdown]
# ## 安裝 Poetry
#
# 在 Colab 環境中安裝 Poetry 工具。

# %%
# !pip install --quiet poetry
# Out:
# Collecting poetry
#   Downloading poetry-1.8.3-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: build<2.0.0,>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from poetry) (1.2.1)
# Requirement already satisfied: cachecontrol<0.15.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (0.14.0)
# Collecting cleo<3.0.0,>=2.1.0 (from poetry)
#   Downloading cleo-2.1.0-py3-none-any.whl.metadata (12 kB)
# Collecting crashtest<0.5.0,>=0.4.1 (from poetry)
#   Downloading crashtest-0.4.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting dulwich<0.22.0,>=0.21.2 (from poetry)
#   Downloading dulwich-0.21.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: fastjsonschema<3.0.0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from poetry) (2.20.0)
# Collecting installer<0.8.0,>=0.7.0 (from poetry)
#   Downloading installer-0.7.0-py3-none-any.whl.metadata (936 bytes)
# Collecting keyring<25.0.0,>=24.0.0 (from poetry)
#   Downloading keyring-24.3.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from poetry) (24.1)
# Requirement already satisfied: pexpect<5.0.0,>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from poetry) (4.9.0)
# Collecting pkginfo<2.0,>=1.10 (from poetry)
#   Downloading pkginfo-1.11.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs<5,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry) (4.2.2)
# Collecting poetry-core==1.9.0 (from poetry)
#   Downloading poetry_core-1.9.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting poetry-plugin-export<2.0.0,>=1.6.0 (from poetry)
#   Downloading poetry_plugin_export-1.8.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pyproject-hooks<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry) (1.1.0)
# Requirement already satisfied: requests<3.0,>=2.26 in /usr/local/lib/python3.10/dist-packages (from poetry) (2.32.3)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from poetry)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: shellingham<2.0,>=1.5 in /usr/local/lib/python3.10/dist-packages (from poetry) (1.5.4)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from poetry) (2.0.1)
# Requirement already satisfied: tomlkit<1.0.0,>=0.11.4 in /usr/local/lib/python3.10/dist-packages (from poetry) (0.13.0)
# Collecting trove-classifiers>=2022.5.19 (from poetry)
#   Downloading trove_classifiers-2024.7.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting virtualenv<21.0.0,>=20.23.0 (from poetry)
#   Downloading virtualenv-20.26.3-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from cachecontrol<0.15.0,>=0.14.0->cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (1.0.8)
# Requirement already satisfied: filelock>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry) (3.15.4)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from cleo<3.0.0,>=2.1.0->poetry)
#   Downloading rapidfuzz-3.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from dulwich<0.22.0,>=0.21.2->poetry) (2.0.7)
# Collecting jaraco.classes (from keyring<25.0.0,>=24.0.0->poetry)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/lib/python3.10/dist-packages (from keyring<25.0.0,>=24.0.0->poetry) (8.2.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.0.0->poetry) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.0.0->poetry) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect<5.0.0,>=4.7.0->poetry) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.26->poetry) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.26->poetry) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.26->poetry) (2024.7.4)
# Collecting distlib<1,>=0.3.7 (from virtualenv<21.0.0,>=20.23.0->poetry)
#   Downloading distlib-0.3.8-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.0.0->poetry) (3.19.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from jaraco.classes->keyring<25.0.0,>=24.0.0->poetry) (10.3.0)
# Downloading poetry-1.8.3-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 952.3 kB/s eta 0:00:00
# Downloading poetry_core-1.9.0-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.5/309.5 kB 12.6 MB/s eta 0:00:00
# Downloading cleo-2.1.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 4.4 MB/s eta 0:00:00
# Downloading crashtest-0.4.1-py3-none-any.whl (7.6 kB)
# Downloading dulwich-0.21.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (514 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 20.1 MB/s eta 0:00:00
# Downloading installer-0.7.0-py3-none-any.whl (453 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 18.9 MB/s eta 0:00:00
# Downloading keyring-24.3.1-py3-none-any.whl (38 kB)
# Downloading pkginfo-1.11.1-py3-none-any.whl (31 kB)
# Downloading poetry_plugin_export-1.8.0-py3-none-any.whl (10 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.6 MB/s eta 0:00:00
# Downloading trove_classifiers-2024.7.2-py3-none-any.whl (13 kB)
# Downloading virtualenv-20.26.3-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 46.1 MB/s eta 0:00:00
# Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 23.2 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 42.7 MB/s eta 0:00:00
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Installing collected packages: trove-classifiers, distlib, virtualenv, rapidfuzz, poetry-core, pkginfo, jaraco.classes, installer, dulwich, crashtest, requests-toolbelt, keyring, cleo, poetry-plugin-export, poetry
#   Attempting uninstall: keyring
#     Found existing installation: keyring 23.5.0
#     Uninstalling keyring-23.5.0:
#       Successfully uninstalled keyring-23.5.0
# Successfully installed cleo-2.1.0 crashtest-0.4.1 distlib-0.3.8 dulwich-0.21.7 installer-0.7.0 jaraco.classes-3.4.0 keyring-24.3.1 pkginfo-1.11.1 poetry-1.8.3 poetry-core-1.9.0 poetry-plugin-export-1.8.0 rapidfuzz-3.9.6 requests-toolbelt-1.0.0 trove-classifiers-2024.7.2 virtualenv-20.26.3

# %% [markdown]
# If you want poetry not to create the virtual environment in the project folder, then run this command !poetry config virtualenvs.in-project false, otherwise, run this command !poetry config virtualenvs.in-project true.
#
# In this tutorial, we will install the packages permanently in Colab, and for convenience, we will create the virtual environment in the project folder.

# %% [markdown]
# ## 配置 Poetry 虛擬環境
# 在本教程中，我們將選擇在 Colab 中永久安裝套件，並將虛擬環境創建在專案文件夾外部，以方便管理。

# %%
import os
os.chdir("/content/translation-agent")

# %%
# !poetry config virtualenvs.in-project false

# %%
# !poetry install --no-ansi
# Out:
# Creating virtualenv translation-agent-P6J8gSLC-py3.10 in /root/.cache/pypoetry/virtualenvs
# Updating dependencies
# Resolving dependencies... (14.1s)Source (pytorch): Authorization error accessing https://download.pytorch.org/whl/nightly/rocm6.0/langchain-core/
# Resolving dependencies... (15.7s)Source (pytorch): Authorization error accessing https://download.pytorch.org/whl/nightly/rocm6.0/langchain-core/
# Resolving dependencies... (20.4s)Source (pytorch): Authorization error accessing https://download.pytorch.org/whl/nightly/rocm6.0/langchain-core/
# Resolving dependencies... (21.6s)Source (pytorch): Authorization error accessing https://download.pytorch.org/whl/nightly/rocm6.0/langchain-core/
# Resolving dependencies... (25.1s)Source (pytorch): Authorization error accessing https://download.pytorch.org/whl/nightly/rocm6.0/langchain-core/
# Resolving dependencies... (26.2s)Source (pytorch): Authorization error accessing https://download.pytorch.org/whl/nightly/rocm6.0/langchain-core/
# Resolving dependencies... (29.9s)Source (pytorch): Authorization error accessing https://download.pytorch.org/whl/nightly/rocm6.0/langchain-core/
# Resolving dependencies... (31.6s)Source (pytorch): Authorization error accessing https://download.pytorch.org/whl/nightly/rocm6.0/langchain-core/
# Resolving dependencies... (33.4s)Source (pytorch): Authorization error accessing https://download.pytorch.org/whl/nightly/rocm6.0/langchain-core/
# Resolving dependencies... (34.3s)
#
# Package operations: 40 installs, 0 updates, 0 removals
#
#   - Installing typing-extensions (4.12.2): Pending...
#   - Installing typing-extensions (4.12.2): Downloading... 0%
#   - Installing typing-extensions (4.12.2): Downloading... 100%
#   - Installing typing-extensions (4.12.2): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing annotated-types (0.7.0): Pending...
#   - Installing certifi (2024.7.4): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing certifi (2024.7.4): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing annotated-types (0.7.0): Downloading... 0%
#   - Installing certifi (2024.7.4): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing certifi (2024.7.4): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing annotated-types (0.7.0): Downloading... 100%
#   - Installing certifi (2024.7.4): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing certifi (2024.7.4): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing annotated-types (0.7.0): Installing...
#   - Installing certifi (2024.7.4): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing certifi (2024.7.4): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing annotated-types (0.7.0)
#   - Installing certifi (2024.7.4): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing certifi (2024.7.4): Downloading... 0%
#   - Installing charset-normalizer (3.3.2): Pending...
#   - Installing idna (3.7): Pending...
#   - Installing pydantic-core (2.20.1): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing idna (3.7): Downloading... 0%
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing idna (3.7): Downloading... 0%
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing charset-normalizer (3.3.2): Downloading... 0%
#   - Installing idna (3.7): Downloading... 0%
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Pending...
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing idna (3.7): Downloading... 100%
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing charset-normalizer (3.3.2): Downloading... 0%
#   - Installing idna (3.7): Downloading... 100%
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing certifi (2024.7.4): Downloading... 100%
#   - Installing charset-normalizer (3.3.2): Downloading... 0%
#   - Installing idna (3.7): Downloading... 100%
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing idna (3.7): Installing...
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing charset-normalizer (3.3.2): Downloading... 0%
#   - Installing idna (3.7): Installing...
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing certifi (2024.7.4): Installing...
#   - Installing charset-normalizer (3.3.2): Downloading... 0%
#   - Installing idna (3.7): Installing...
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing idna (3.7): Installing...
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing charset-normalizer (3.3.2): Downloading... 100%
#   - Installing idna (3.7): Installing...
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 0%
#   - Installing urllib3 (2.2.2): Downloading... 100%
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing idna (3.7): Installing...
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing charset-normalizer (3.3.2): Installing...
#   - Installing idna (3.7): Installing...
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing idna (3.7)
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing charset-normalizer (3.3.2): Installing...
#   - Installing idna (3.7)
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing certifi (2024.7.4)
#   - Installing charset-normalizer (3.3.2): Installing...
#   - Installing idna (3.7)
#   - Installing pydantic-core (2.20.1): Downloading... 0%
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing pydantic-core (2.20.1): Downloading... 50%
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing idna (3.7)
#   - Installing pydantic-core (2.20.1): Downloading... 50%
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing charset-normalizer (3.3.2)
#   - Installing idna (3.7)
#   - Installing pydantic-core (2.20.1): Downloading... 50%
#   - Installing urllib3 (2.2.2): Installing...
#   - Installing urllib3 (2.2.2)
#   - Installing urllib3 (2.2.2)
#   - Installing pydantic-core (2.20.1): Downloading... 100%
#   - Installing urllib3 (2.2.2)
#   - Installing urllib3 (2.2.2)
#   - Installing pydantic-core (2.20.1): Installing...
#   - Installing urllib3 (2.2.2)
#   - Installing urllib3 (2.2.2)
#   - Installing pydantic-core (2.20.1)
#   - Installing urllib3 (2.2.2)
#   - Installing exceptiongroup (1.2.2): Pending...
#   - Installing h11 (0.14.0): Pending...
#   - Installing jsonpointer (3.0.0): Pending...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Pending...
#   - Installing h11 (0.14.0): Pending...
#   - Installing jsonpointer (3.0.0): Pending...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Pending...
#   - Installing exceptiongroup (1.2.2): Downloading... 0%
#   - Installing h11 (0.14.0): Pending...
#   - Installing jsonpointer (3.0.0): Pending...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Pending...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Pending...
#   - Installing jsonpointer (3.0.0): Downloading... 0%
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Pending...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Pending...
#   - Installing jsonpointer (3.0.0): Downloading... 100%
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Pending...
#   - Installing h11 (0.14.0): Pending...
#   - Installing jsonpointer (3.0.0): Downloading... 100%
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Pending...
#   - Installing exceptiongroup (1.2.2): Downloading... 100%
#   - Installing h11 (0.14.0): Pending...
#   - Installing jsonpointer (3.0.0): Downloading... 100%
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Pending...
#   - Installing requests (2.32.3): Downloading... 0%
#   - Installing jsonpointer (3.0.0): Downloading... 100%
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Downloading... 0%
#   - Installing h11 (0.14.0): Downloading... 0%
#   - Installing jsonpointer (3.0.0): Downloading... 100%
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Downloading... 0%
#   - Installing h11 (0.14.0): Downloading... 0%
#   - Installing jsonpointer (3.0.0): Downloading... 100%
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Downloading... 0%
#   - Installing exceptiongroup (1.2.2): Installing...
#   - Installing h11 (0.14.0): Downloading... 0%
#   - Installing jsonpointer (3.0.0): Downloading... 100%
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Pending...
#   - Installing requests (2.32.3): Downloading... 0%
#   - Installing requests (2.32.3): Downloading... 0%
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Downloading... 0%
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Downloading... 0%
#   - Installing jsonpointer (3.0.0): Installing...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Downloading... 0%
#   - Installing requests (2.32.3): Downloading... 100%
#   - Installing jsonpointer (3.0.0): Installing...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Downloading... 100%
#   - Installing h11 (0.14.0): Downloading... 100%
#   - Installing jsonpointer (3.0.0): Installing...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Downloading... 100%
#   - Installing requests (2.32.3): Installing...
#   - Installing jsonpointer (3.0.0): Installing...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Installing...
#   - Installing h11 (0.14.0): Installing...
#   - Installing jsonpointer (3.0.0): Installing...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Installing...
#   - Installing h11 (0.14.0): Installing...
#   - Installing jsonpointer (3.0.0): Installing...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Installing...
#   - Installing exceptiongroup (1.2.2)
#   - Installing h11 (0.14.0): Installing...
#   - Installing jsonpointer (3.0.0): Installing...
#   - Installing orjson (3.10.7): Pending...
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing orjson (3.10.7): Downloading... 0%
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing orjson (3.10.7): Downloading... 0%
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing jsonpointer (3.0.0)
#   - Installing orjson (3.10.7): Downloading... 0%
#   - Installing pydantic (2.8.2): Downloading... 0%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Pending...
#   - Installing sniffio (1.3.1): Downloading... 0%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Downloading... 0%
#   - Installing pydantic (2.8.2): Downloading... 100%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Downloading... 0%
#   - Installing sniffio (1.3.1): Downloading... 100%
#   - Installing sniffio (1.3.1): Installing...
#   - Installing pydantic (2.8.2): Downloading... 100%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Installing...
#   - Installing orjson (3.10.7): Downloading... 100%
#   - Installing pydantic (2.8.2): Downloading... 100%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Installing...
#   - Installing pydantic (2.8.2): Downloading... 100%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Installing...
#   - Installing orjson (3.10.7): Installing...
#   - Installing pydantic (2.8.2): Downloading... 100%
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Installing...
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Installing...
#   - Installing pydantic (2.8.2): Installing...
#   - Installing requests (2.32.3): Installing...
#   - Installing sniffio (1.3.1): Installing...
#   - Installing sniffio (1.3.1): Installing...
#   - Installing requests (2.32.3)
#   - Installing sniffio (1.3.1): Installing...
#   - Installing jsonpointer (3.0.0)
#   - Installing orjson (3.10.7): Installing...
#   - Installing pydantic (2.8.2): Installing...
#   - Installing requests (2.32.3)
#   - Installing sniffio (1.3.1): Installing...
#   - Installing h11 (0.14.0)
#   - Installing jsonpointer (3.0.0)
#   - Installing orjson (3.10.7): Installing...
#   - Installing pydantic (2.8.2): Installing...
#   - Installing requests (2.32.3)
#   - Installing sniffio (1.3.1): Installing...
#   - Installing sniffio (1.3.1)
#   - Installing pydantic (2.8.2): Installing...
#   - Installing requests (2.32.3)
#   - Installing sniffio (1.3.1)
#   - Installing orjson (3.10.7)
#   - Installing pydantic (2.8.2): Installing...
#   - Installing requests (2.32.3)
#   - Installing sniffio (1.3.1)
#   - Installing requests (2.32.3)
#   - Installing sniffio (1.3.1)
#   - Installing pydantic (2.8.2)
#   - Installing requests (2.32.3)
#   - Installing sniffio (1.3.1)
#   - Installing anyio (4.4.0): Pending...
#   - Installing httpcore (1.0.5): Pending...
#   - Installing jsonpatch (1.33): Pending...
#   - Installing langsmith (0.1.99): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing jsonpatch (1.33): Pending...
#   - Installing langsmith (0.1.99): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing httpcore (1.0.5): Downloading... 0%
#   - Installing jsonpatch (1.33): Pending...
#   - Installing langsmith (0.1.99): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing langsmith (0.1.99): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing jsonpatch (1.33): Downloading... 0%
#   - Installing langsmith (0.1.99): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing packaging (23.2): Pending...
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing langsmith (0.1.99): Downloading... 0%
#   - Installing packaging (23.2): Pending...
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing httpcore (1.0.5): Downloading... 0%
#   - Installing jsonpatch (1.33): Downloading... 0%
#   - Installing langsmith (0.1.99): Downloading... 0%
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing anyio (4.4.0): Downloading... 0%
#   - Installing httpcore (1.0.5): Downloading... 0%
#   - Installing jsonpatch (1.33): Downloading... 0%
#   - Installing langsmith (0.1.99): Downloading... 0%
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing langsmith (0.1.99): Downloading... 0%
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing jsonpatch (1.33): Downloading... 100%
#   - Installing langsmith (0.1.99): Downloading... 0%
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing httpcore (1.0.5): Downloading... 0%
#   - Installing jsonpatch (1.33): Downloading... 100%
#   - Installing langsmith (0.1.99): Downloading... 0%
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing anyio (4.4.0): Downloading... 100%
#   - Installing httpcore (1.0.5): Downloading... 0%
#   - Installing jsonpatch (1.33): Downloading... 100%
#   - Installing langsmith (0.1.99): Downloading... 0%
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Pending...
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing httpcore (1.0.5): Downloading... 0%
#   - Installing jsonpatch (1.33): Downloading... 100%
#   - Installing langsmith (0.1.99): Downloading... 0%
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing anyio (4.4.0): Installing...
#   - Installing httpcore (1.0.5): Downloading... 0%
#   - Installing jsonpatch (1.33): Downloading... 100%
#   - Installing langsmith (0.1.99): Downloading... 0%
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing langsmith (0.1.99): Downloading... 100%
#   - Installing packaging (23.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing packaging (23.2): Downloading... 100%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing langsmith (0.1.99): Downloading... 100%
#   - Installing packaging (23.2): Downloading... 100%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing jsonpatch (1.33): Installing...
#   - Installing langsmith (0.1.99): Downloading... 100%
#   - Installing packaging (23.2): Downloading... 100%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing jsonpatch (1.33): Installing...
#   - Installing langsmith (0.1.99): Downloading... 100%
#   - Installing packaging (23.2): Downloading... 100%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing httpcore (1.0.5): Downloading... 100%
#   - Installing jsonpatch (1.33): Installing...
#   - Installing langsmith (0.1.99): Downloading... 100%
#   - Installing packaging (23.2): Downloading... 100%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing packaging (23.2): Installing...
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing packaging (23.2): Installing...
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing langsmith (0.1.99): Installing...
#   - Installing packaging (23.2): Installing...
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing jsonpatch (1.33): Installing...
#   - Installing langsmith (0.1.99): Installing...
#   - Installing packaging (23.2): Installing...
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing httpcore (1.0.5): Installing...
#   - Installing jsonpatch (1.33): Installing...
#   - Installing langsmith (0.1.99): Installing...
#   - Installing packaging (23.2): Installing...
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing langsmith (0.1.99): Installing...
#   - Installing packaging (23.2): Installing...
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.99): Installing...
#   - Installing packaging (23.2): Installing...
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing six (1.16.0): Pending...
#   - Installing six (1.16.0): Downloading... 0%
#   - Installing six (1.16.0): Downloading... 100%
#   - Installing six (1.16.0): Installing...
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing six (1.16.0): Installing...
#   - Installing packaging (23.2)
#   - Installing pyyaml (6.0.2): Downloading... 0%
#   - Installing six (1.16.0): Installing...
#   - Installing tenacity (8.5.0): Pending...
#   - Installing six (1.16.0): Installing...
#   - Installing tenacity (8.5.0): Pending...
#   - Installing pyyaml (6.0.2): Downloading... 80%
#   - Installing six (1.16.0): Installing...
#   - Installing tenacity (8.5.0): Pending...
#   - Installing tenacity (8.5.0): Pending...
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0): Pending...
#   - Installing tenacity (8.5.0): Downloading... 0%
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.99): Installing...
#   - Installing packaging (23.2)
#   - Installing pyyaml (6.0.2): Downloading... 80%
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0): Downloading... 0%
#   - Installing httpcore (1.0.5)
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.99): Installing...
#   - Installing packaging (23.2)
#   - Installing pyyaml (6.0.2): Downloading... 80%
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0): Downloading... 0%
#   - Installing tenacity (8.5.0): Downloading... 100%
#   - Installing httpcore (1.0.5)
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.99): Installing...
#   - Installing packaging (23.2)
#   - Installing pyyaml (6.0.2): Downloading... 80%
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0): Downloading... 100%
#   - Installing anyio (4.4.0)
#   - Installing httpcore (1.0.5)
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.99): Installing...
#   - Installing packaging (23.2)
#   - Installing pyyaml (6.0.2): Downloading... 80%
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0): Downloading... 100%
#   - Installing tenacity (8.5.0): Installing...
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0): Installing...
#   - Installing pyyaml (6.0.2): Downloading... 100%
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0): Installing...
#   - Installing tenacity (8.5.0)
#   - Installing packaging (23.2)
#   - Installing pyyaml (6.0.2): Downloading... 100%
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0)
#   - Installing langsmith (0.1.99)
#   - Installing packaging (23.2)
#   - Installing pyyaml (6.0.2): Downloading... 100%
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0)
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0)
#   - Installing pyyaml (6.0.2): Installing...
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0)
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0)
#   - Installing pyyaml (6.0.2)
#   - Installing six (1.16.0)
#   - Installing tenacity (8.5.0)
#   - Installing asttokens (2.4.1): Pending...
#   - Installing chardet (5.2.0): Pending...
#   - Installing colorama (0.4.6): Pending...
#   - Installing distro (1.9.0): Pending...
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing distro (1.9.0): Pending...
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing colorama (0.4.6): Downloading... 0%
#   - Installing distro (1.9.0): Pending...
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing chardet (5.2.0): Pending...
#   - Installing colorama (0.4.6): Downloading... 0%
#   - Installing distro (1.9.0): Pending...
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing asttokens (2.4.1): Downloading... 0%
#   - Installing chardet (5.2.0): Pending...
#   - Installing colorama (0.4.6): Downloading... 0%
#   - Installing distro (1.9.0): Pending...
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing colorama (0.4.6): Downloading... 0%
#   - Installing distro (1.9.0): Pending...
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing chardet (5.2.0): Downloading... 0%
#   - Installing colorama (0.4.6): Downloading... 0%
#   - Installing distro (1.9.0): Pending...
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing distro (1.9.0): Pending...
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing colorama (0.4.6): Downloading... 100%
#   - Installing distro (1.9.0): Pending...
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing distro (1.9.0): Downloading... 0%
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing chardet (5.2.0): Downloading... 0%
#   - Installing colorama (0.4.6): Downloading... 100%
#   - Installing distro (1.9.0): Downloading... 0%
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing asttokens (2.4.1): Downloading... 100%
#   - Installing chardet (5.2.0): Downloading... 0%
#   - Installing colorama (0.4.6): Downloading... 100%
#   - Installing distro (1.9.0): Downloading... 0%
#   - Installing executing (2.0.1): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing httpx (0.27.0): Pending...
#   - Installing executing (2.0.1): Downloading... 0%
#   - Installing httpx (0.27.0): Pending...
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing distro (1.9.0): Downloading... 0%
#   - Installing executing (2.0.1): Downloading... 0%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing colorama (0.4.6): Installing...
#   - Installing distro (1.9.0): Downloading... 0%
#   - Installing executing (2.0.1): Downloading... 0%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing chardet (5.2.0): Downloading... 0%
#   - Installing colorama (0.4.6): Installing...
#   - Installing distro (1.9.0): Downloading... 0%
#   - Installing executing (2.0.1): Downloading... 0%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing asttokens (2.4.1): Installing...
#   - Installing chardet (5.2.0): Downloading... 0%
#   - Installing colorama (0.4.6): Installing...
#   - Installing distro (1.9.0): Downloading... 0%
#   - Installing executing (2.0.1): Downloading... 0%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing executing (2.0.1): Downloading... 0%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing distro (1.9.0): Downloading... 100%
#   - Installing executing (2.0.1): Downloading... 0%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing executing (2.0.1): Downloading... 100%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing executing (2.0.1): Downloading... 100%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing distro (1.9.0): Installing...
#   - Installing executing (2.0.1): Downloading... 100%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing colorama (0.4.6): Installing...
#   - Installing distro (1.9.0): Installing...
#   - Installing executing (2.0.1): Downloading... 100%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing chardet (5.2.0): Downloading... 100%
#   - Installing colorama (0.4.6): Installing...
#   - Installing distro (1.9.0): Installing...
#   - Installing executing (2.0.1): Downloading... 100%
#   - Installing httpx (0.27.0): Downloading... 0%
#   - Installing httpx (0.27.0): Downloading... 100%
#   - Installing httpx (0.27.0): Downloading... 100%
#   - Installing executing (2.0.1): Installing...
#   - Installing httpx (0.27.0): Downloading... 100%
#   - Installing httpx (0.27.0): Installing...
#   - Installing colorama (0.4.6): Installing...
#   - Installing distro (1.9.0): Installing...
#   - Installing executing (2.0.1): Installing...
#   - Installing httpx (0.27.0): Installing...
#   - Installing chardet (5.2.0): Installing...
#   - Installing colorama (0.4.6): Installing...
#   - Installing distro (1.9.0): Installing...
#   - Installing executing (2.0.1): Installing...
#   - Installing httpx (0.27.0): Installing...
#   - Installing chardet (5.2.0): Installing...
#   - Installing colorama (0.4.6): Installing...
#   - Installing distro (1.9.0): Installing...
#   - Installing executing (2.0.1): Installing...
#   - Installing httpx (0.27.0): Installing...
#   - Installing asttokens (2.4.1)
#   - Installing chardet (5.2.0): Installing...
#   - Installing colorama (0.4.6): Installing...
#   - Installing distro (1.9.0): Installing...
#   - Installing executing (2.0.1): Installing...
#   - Installing httpx (0.27.0): Installing...
#   - Installing distro (1.9.0): Installing...
#   - Installing executing (2.0.1): Installing...
#   - Installing httpx (0.27.0): Installing...
#   - Installing colorama (0.4.6)
#   - Installing distro (1.9.0): Installing...
#   - Installing executing (2.0.1): Installing...
#   - Installing httpx (0.27.0): Installing...
#   - Installing jiter (0.5.0): Pending...
#   - Installing langchain-core (0.1.52): Pending...
#   - Installing executing (2.0.1): Installing...
#   - Installing httpx (0.27.0): Installing...
#   - Installing jiter (0.5.0): Pending...
#   - Installing langchain-core (0.1.52): Pending...
#   - Installing distro (1.9.0)
#   - Installing executing (2.0.1): Installing...
#   - Installing httpx (0.27.0): Installing...
#   - Installing jiter (0.5.0): Pending...
#   - Installing langchain-core (0.1.52): Pending...
#   - Installing pygments (2.18.0): Pending...
#   - Installing pygments (2.18.0): Pending...
#   - Installing langchain-core (0.1.52): Downloading... 0%
#   - Installing pygments (2.18.0): Pending...
#   - Installing httpx (0.27.0): Installing...
#   - Installing jiter (0.5.0): Pending...
#   - Installing langchain-core (0.1.52): Downloading... 0%
#   - Installing pygments (2.18.0): Pending...
#   - Installing executing (2.0.1)
#   - Installing httpx (0.27.0): Installing...
#   - Installing jiter (0.5.0): Pending...
#   - Installing langchain-core (0.1.52): Downloading... 0%
#   - Installing pygments (2.18.0): Pending...
#   - Installing regex (2024.7.24): Pending...
#   - Installing langchain-core (0.1.52): Downloading... 0%
#   - Installing pygments (2.18.0): Pending...
#   - Installing regex (2024.7.24): Pending...
#   - Installing jiter (0.5.0): Downloading... 0%
#   - Installing langchain-core (0.1.52): Downloading... 0%
#   - Installing pygments (2.18.0): Pending...
#   - Installing regex (2024.7.24): Pending...
#   - Installing regex (2024.7.24): Pending...
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Pending...
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing jiter (0.5.0): Downloading... 0%
#   - Installing langchain-core (0.1.52): Downloading... 0%
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing httpx (0.27.0)
#   - Installing jiter (0.5.0): Downloading... 0%
#   - Installing langchain-core (0.1.52): Downloading... 0%
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing tqdm (4.66.5): Pending...
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing tqdm (4.66.5): Pending...
#   - Installing langchain-core (0.1.52): Downloading... 100%
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing tqdm (4.66.5): Pending...
#   - Installing langchain-core (0.1.52): Downloading... 100%
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing tqdm (4.66.5): Pending...
#   - Installing jiter (0.5.0): Downloading... 100%
#   - Installing langchain-core (0.1.52): Downloading... 100%
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing tqdm (4.66.5): Pending...
#   - Installing tqdm (4.66.5): Downloading... 0%
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing tqdm (4.66.5): Downloading... 0%
#   - Installing langchain-core (0.1.52): Installing...
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing tqdm (4.66.5): Downloading... 0%
#   - Installing langchain-core (0.1.52): Installing...
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing tqdm (4.66.5): Downloading... 0%
#   - Installing jiter (0.5.0): Installing...
#   - Installing langchain-core (0.1.52): Installing...
#   - Installing pygments (2.18.0): Downloading... 0%
#   - Installing regex (2024.7.24): Downloading... 0%
#   - Installing tqdm (4.66.5): Downloading... 0%
#   - Installing tqdm (4.66.5): Downloading... 100%
#   - Installing tqdm (4.66.5): Installing...
#   - Installing tqdm (4.66.5): Installing...
#   - Installing regex (2024.7.24): Downloading... 100%
#   - Installing tqdm (4.66.5): Installing...
#   - Installing regex (2024.7.24): Downloading... 100%
#   - Installing tqdm (4.66.5): Installing...
#   - Installing pygments (2.18.0): Downloading... 50%
#   - Installing regex (2024.7.24): Downloading... 100%
#   - Installing tqdm (4.66.5): Installing...
#   - Installing colorama (0.4.6)
#   - Installing distro (1.9.0)
#   - Installing executing (2.0.1)
#   - Installing httpx (0.27.0)
#   - Installing jiter (0.5.0): Installing...
#   - Installing langchain-core (0.1.52): Installing...
#   - Installing pygments (2.18.0): Downloading... 50%
#   - Installing regex (2024.7.24): Downloading... 100%
#   - Installing tqdm (4.66.5): Installing...
#   - Installing chardet (5.2.0)
#   - Installing colorama (0.4.6)
#   - Installing distro (1.9.0)
#   - Installing executing (2.0.1)
#   - Installing httpx (0.27.0)
#   - Installing jiter (0.5.0): Installing...
#   - Installing langchain-core (0.1.52): Installing...
#   - Installing pygments (2.18.0): Downloading... 50%
#   - Installing regex (2024.7.24): Downloading... 100%
#   - Installing tqdm (4.66.5): Installing...
#   - Installing langchain-core (0.1.52): Installing...
#   - Installing pygments (2.18.0): Downloading... 50%
#   - Installing regex (2024.7.24): Downloading... 100%
#   - Installing tqdm (4.66.5): Installing...
#   - Installing jiter (0.5.0)
#   - Installing langchain-core (0.1.52): Installing...
#   - Installing pygments (2.18.0): Downloading... 50%
#   - Installing regex (2024.7.24): Downloading... 100%
#   - Installing tqdm (4.66.5): Installing...
#   - Installing tqdm (4.66.5): Installing...
#   - Installing regex (2024.7.24): Installing...
#   - Installing tqdm (4.66.5): Installing...
#   - Installing tqdm (4.66.5)
#   - Installing regex (2024.7.24): Installing...
#   - Installing tqdm (4.66.5)
#   - Installing pygments (2.18.0): Downloading... 100%
#   - Installing regex (2024.7.24): Installing...
#   - Installing tqdm (4.66.5)
#   - Installing regex (2024.7.24): Installing...
#   - Installing tqdm (4.66.5)
#   - Installing pygments (2.18.0): Installing...
#   - Installing regex (2024.7.24): Installing...
#   - Installing tqdm (4.66.5)
#   - Installing tqdm (4.66.5)
#   - Installing regex (2024.7.24)
#   - Installing tqdm (4.66.5)
#   - Installing pygments (2.18.0): Installing...
#   - Installing regex (2024.7.24)
#   - Installing tqdm (4.66.5)
#   - Installing langchain-core (0.1.52)
#   - Installing pygments (2.18.0): Installing...
#   - Installing regex (2024.7.24)
#   - Installing tqdm (4.66.5)
#   - Installing regex (2024.7.24)
#   - Installing tqdm (4.66.5)
#   - Installing pygments (2.18.0)
#   - Installing regex (2024.7.24)
#   - Installing tqdm (4.66.5)
#   - Installing icecream (2.1.3): Pending...
#   - Installing joblib (1.4.2): Pending...
#   - Installing langchain-text-splitters (0.0.1): Pending...
#   - Installing openai (1.41.0): Pending...
#   - Installing pysrt (1.1.2): Pending...
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing langchain-text-splitters (0.0.1): Pending...
#   - Installing openai (1.41.0): Pending...
#   - Installing pysrt (1.1.2): Pending...
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing joblib (1.4.2): Downloading... 0%
#   - Installing langchain-text-splitters (0.0.1): Pending...
#   - Installing openai (1.41.0): Pending...
#   - Installing pysrt (1.1.2): Pending...
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing openai (1.41.0): Pending...
#   - Installing pysrt (1.1.2): Pending...
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing langchain-text-splitters (0.0.1): Downloading... 0%
#   - Installing openai (1.41.0): Pending...
#   - Installing pysrt (1.1.2): Pending...
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing joblib (1.4.2): Downloading... 0%
#   - Installing langchain-text-splitters (0.0.1): Downloading... 0%
#   - Installing openai (1.41.0): Pending...
#   - Installing pysrt (1.1.2): Pending...
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing icecream (2.1.3): Downloading... 0%
#   - Installing joblib (1.4.2): Downloading... 0%
#   - Installing langchain-text-splitters (0.0.1): Downloading... 0%
#   - Installing openai (1.41.0): Pending...
#   - Installing pysrt (1.1.2): Pending...
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing pysrt (1.1.2): Pending...
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Pending...
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing pysrt (1.1.2): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing joblib (1.4.2): Downloading... 0%
#   - Installing langchain-text-splitters (0.0.1): Downloading... 0%
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing icecream (2.1.3): Downloading... 100%
#   - Installing joblib (1.4.2): Downloading... 0%
#   - Installing langchain-text-splitters (0.0.1): Downloading... 0%
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Pending...
#   - Installing python-dotenv (1.0.1): Downloading... 0%
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Downloading... 0%
#   - Installing langchain-text-splitters (0.0.1): Downloading... 100%
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Downloading... 0%
#   - Installing joblib (1.4.2): Downloading... 0%
#   - Installing langchain-text-splitters (0.0.1): Downloading... 100%
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Downloading... 0%
#   - Installing icecream (2.1.3): Installing...
#   - Installing joblib (1.4.2): Downloading... 0%
#   - Installing langchain-text-splitters (0.0.1): Downloading... 100%
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Downloading... 100%
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Downloading... 100%
#   - Installing langchain-text-splitters (0.0.1): Installing...
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Downloading... 0%
#   - Installing python-dotenv (1.0.1): Downloading... 100%
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing pysrt (1.1.2): Downloading... 100%
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing langchain-text-splitters (0.0.1): Installing...
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Downloading... 100%
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing joblib (1.4.2): Downloading... 100%
#   - Installing langchain-text-splitters (0.0.1): Installing...
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Downloading... 100%
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing joblib (1.4.2): Downloading... 100%
#   - Installing langchain-text-splitters (0.0.1): Installing...
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing icecream (2.1.3)
#   - Installing joblib (1.4.2): Downloading... 100%
#   - Installing langchain-text-splitters (0.0.1): Installing...
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing tiktoken (0.6.0): Pending...
#   - Installing langchain-text-splitters (0.0.1): Installing...
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing tiktoken (0.6.0): Pending...
#   - Installing joblib (1.4.2): Installing...
#   - Installing langchain-text-splitters (0.0.1): Installing...
#   - Installing openai (1.41.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing tiktoken (0.6.0): Pending...
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing tiktoken (0.6.0): Pending...
#   - Installing openai (1.41.0): Downloading... 100%
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing tiktoken (0.6.0): Pending...
#   - Installing openai (1.41.0): Downloading... 100%
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing tiktoken (0.6.0): Pending...
#   - Installing langchain-text-splitters (0.0.1)
#   - Installing openai (1.41.0): Downloading... 100%
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1): Installing...
#   - Installing tiktoken (0.6.0): Pending...
#   - Installing tiktoken (0.6.0): Pending...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0): Pending...
#   - Installing tiktoken (0.6.0): Downloading... 0%
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0): Downloading... 0%
#   - Installing openai (1.41.0): Installing...
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0): Downloading... 0%
#   - Installing tiktoken (0.6.0): Downloading... 80%
#   - Installing tiktoken (0.6.0): Downloading... 100%
#   - Installing tiktoken (0.6.0): Installing...
#   - Installing langchain-text-splitters (0.0.1)
#   - Installing openai (1.41.0): Installing...
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0): Installing...
#   - Installing joblib (1.4.2)
#   - Installing langchain-text-splitters (0.0.1)
#   - Installing openai (1.41.0): Installing...
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0): Installing...
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0): Installing...
#   - Installing openai (1.41.0)
#   - Installing pysrt (1.1.2): Preparing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0): Installing...
#   - Installing tiktoken (0.6.0)
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0)
#   - Installing pysrt (1.1.2): Installing...
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0)
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0)
#   - Installing pysrt (1.1.2)
#   - Installing python-dotenv (1.0.1)
#   - Installing tiktoken (0.6.0)
#
# Writing lock file
#
# Installing the current project: translation-agent (0.1.0)Installing the current project: translation-agent (0.1.0)

# %% [markdown]
# > 提示：如果您希望 Poetry 在專案文件夾內創建虛擬環境，可以將配置命令改為 !poetry config virtualenvs.in-project true。

# %% [markdown]
# 2.4 Run project

# %% [markdown]
# ## 執行專案
#
# 安裝完依賴後，我們需要設置 Python 解釋器來使用 Poetry 創建的虛擬環境。

# %%
import subprocess

# 執行 ls 命令並獲取結果
result = subprocess.run(['ls', '/root/.cache/pypoetry/virtualenvs'], stdout=subprocess.PIPE)

# 將結果轉換為字串
virtualenv_name = result.stdout.decode('utf-8').strip()

print(f"Virtualenv Name: {virtualenv_name}")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Virtualenv Name: translation-agent-P6J8gSLC-py3.10

# %%
# 構建路徑
path = f'/root/.cache/pypoetry/virtualenvs/{virtualenv_name}/lib'

# 執行 ls 命令並獲取結果
result2 = subprocess.run(['ls', path], stdout=subprocess.PIPE)

# 將結果轉換為字串並去除多餘的換行符
python_version = result2.stdout.decode('utf-8').strip()

print(f"Python Version Directory: {python_version}")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Python Version Directory: python3.10

# %%
import sys
Virtual_Environment_Name=virtualenv_name
Python_Version = python_version
sys.path.append(f"/root/.cache/pypoetry/virtualenvs/{Virtual_Environment_Name}/lib/{Python_Version}/site-packages")

import os
os.chdir("/content/translation-agent")

# %% [markdown]
# ## 設置環境變數
#
# 為了使用 OpenAI API，我們需要設置 OPENAI_API_KEY 環境變數。在 Colab 中，我們可以使用 userdata 來安全地存儲和訪問 API 密鑰。

# %% [markdown]
# 我們需要設置 環境變數 `OPENAI_API_KEY` ，可以直接完成，如下所示：

# %%
import os
import getpass
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# %% [markdown]
# > 安全提示：請確保不要直接在代碼中暴露您的 API 密鑰。使用 Colab 的 userdata 功能是一種安全的做法。

# %% [markdown]
# ## 優化 Colab 輸出格式
#
# 為了提高代碼輸出的可讀性，我們可以設置一些 CSS 樣式：

# %% [markdown]
# 縮減排版
#
# 參考資料：https://stackoverflow.com/questions/58890109/line-wrapping-in-collaboratory-google-results

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %% [markdown]
# 這段代碼將確保長行的代碼能夠自動換行，提高可讀性。

# %% [markdown]
# ## 運行示例腳本
# 最後，我們可以使用 Poetry 來運行專案中的示例腳本：

# %%
# !poetry run python examples/example_script.py
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 原始語句:
#
# 歡迎來到台灣，你可以使用北北基悠遊卡暢遊整個大台北，三天內的旅遊都可以任意搭乘交通工具，包含：高鐵、台鐵、捷運。祝你有美好的一天！
# ------------
#
# ic| num_tokens_in_text: 86
# ic| 'Translating text as a single chunk'
# 翻譯結果:
#
# Welcome to Taiwan! You can use the EasyCard to explore the entire Taipei, New Taipei, and Keelung area. For the next three days, enjoy unlimited access to various modes of transportation, including the High-Speed Rail, Taiwan Railways, and the MRT. Wishing you a fantastic day ahead!

# %% [markdown]
# 參考資料：
# 1. https://github.com/Heng-xiu/translation-agent
# 2. https://github.com/elise-chin/poetry-and-colab/blob/main/Using_python_poetry_in_Google_Colab.ipynb
# 3. https://gist.github.com/DPaletti/da7729c35ba7f9274c3635849608b7bc
